# %% [markdown]
# # The notebook '2_learn_model' uses numpy arrays generated by '1_read_dicoms' for training of models that predict brain and ventricle masks from patient images. Model parameters are stored in an output file which is used as input in the next notebook '3_make_model_predictions'.
#
# The following steps are required before running:
# 1. Successfuly complete running notebook '1_read_dicoms'
# 2. Have access to run this script on a computer with a GPU
# 3. Specify local directory of input numpy arrays and output model files

# %% [markdown]
# # Part 1: Training on MRI images with masks from ATLAS

# %% [markdown]
# # Part 2: Training on CT images with masks from clinicians

# %% [markdown]
# # Part 3: Training on MRI images with masks from clinicians

# %% [markdown]
# # Part 4: Training with transfer learning (MRI-to-MRI)

# %% [markdown]
# # Part 5: Training with transfer learning (MRI-to-CT)
